# %%
import requests
from bs4 import BeautifulSoup
from IPython import display
import os
import signal
import subprocess
import time

# %%
while True:
    kitten = requests.get('http://thecatapi.com/api/images/get?format=src&type=gif')
    file = open('kitty.gif', 'wb')
    file.write(kitten.content)
    file.close()
    cmd = "viewnior kitty.gif"
    pro = subprocess.Popen(cmd, stdout=subprocess.PIPE, 
                           shell=True, preexec_fn=os.setsid) 
    time.sleep(5)
    os.killpg(pro.pid, signal.SIGTERM)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-29-8e8eff673603> in <module>()
#       1 while True:
# ----> 2     kitten = requests.get('http://thecatapi.com/api/images/get?format=src&type=gif')
#       3     file = open('kitty.gif', 'wb')
#       4     file.write(kitten.content)
#       5     file.close()
#
# /home/chio/.virtualenvs/sEnv/lib/python3.5/site-packages/requests/api.py in get(url, params, **kwargs)
#      67
#      68     kwargs.setdefault('allow_redirects', True)
# ---> 69     return request('get', url, params=params, **kwargs)
#      70
#      71
#
# /home/chio/.virtualenvs/sEnv/lib/python3.5/site-packages/requests/api.py in request(method, url, **kwargs)
#      48
#      49     session = sessions.Session()
# ---> 50     response = session.request(method=method, url=url, **kwargs)
#      51     # By explicitly closing the session, we avoid leaving sockets open which
#      52     # can trigger a ResourceWarning in some cases, and look like a memory leak
#
# /home/chio/.virtualenvs/sEnv/lib/python3.5/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     466         }
#     467         send_kwargs.update(settings)
# --> 468         resp = self.send(prep, **send_kwargs)
#     469
#     470         return resp
#
# /home/chio/.virtualenvs/sEnv/lib/python3.5/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     595
#     596         # Resolve redirects if allowed.
# --> 597         history = [resp for resp in gen] if allow_redirects else []
#     598
#     599         # Shuffle things around if there's history.
#
# /home/chio/.virtualenvs/sEnv/lib/python3.5/site-packages/requests/sessions.py in <listcomp>(.0)
#     595
#     596         # Resolve redirects if allowed.
# --> 597         history = [resp for resp in gen] if allow_redirects else []
#     598
#     599         # Shuffle things around if there's history.
#
# /home/chio/.virtualenvs/sEnv/lib/python3.5/site-packages/requests/sessions.py in resolve_redirects(self, resp, req, stream, timeout, verify, cert, proxies, **adapter_kwargs)
#     193                 proxies=proxies,
#     194                 allow_redirects=False,
# --> 195                 **adapter_kwargs
#     196             )
#     197
#
# /home/chio/.virtualenvs/sEnv/lib/python3.5/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     574
#     575         # Send the request
# --> 576         r = adapter.send(request, **kwargs)
#     577
#     578         # Total elapsed time of the request (approximately)
#
# /home/chio/.virtualenvs/sEnv/lib/python3.5/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     368                     decode_content=False,
#     369                     retries=self.max_retries,
# --> 370                     timeout=timeout
#     371                 )
#     372
#
# /home/chio/.virtualenvs/sEnv/lib/python3.5/site-packages/requests/packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, **response_kw)
#     557             httplib_response = self._make_request(conn, method, url,
#     558                                                   timeout=timeout_obj,
# --> 559                                                   body=body, headers=headers)
#     560
#     561             # If we're going to release the connection in ``finally:``, then
#
# /home/chio/.virtualenvs/sEnv/lib/python3.5/site-packages/requests/packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, **httplib_request_kw)
#     351         # conn.request() calls httplib.*.request, not the method in
#     352         # urllib3.request. It also calls makefile (recv) on the socket.
# --> 353         conn.request(method, url, **httplib_request_kw)
#     354
#     355         # Reset the timeout for the recv() on the socket
#
# /usr/lib64/python3.5/http/client.py in request(self, method, url, body, headers)
#    1081     def request(self, method, url, body=None, headers={}):
#    1082         """Send a complete request to the server."""
# -> 1083         self._send_request(method, url, body, headers)
#    1084
#    1085     def _set_content_length(self, body, method):
#
# /usr/lib64/python3.5/http/client.py in _send_request(self, method, url, body, headers)
#    1126             # default charset of iso-8859-1.
#    1127             body = body.encode('iso-8859-1')
# -> 1128         self.endheaders(body)
#    1129
#    1130     def getresponse(self):
#
# /usr/lib64/python3.5/http/client.py in endheaders(self, message_body)
#    1077         else:
#    1078             raise CannotSendHeader()
# -> 1079         self._send_output(message_body)
#    1080
#    1081     def request(self, method, url, body=None, headers={}):
#
# /usr/lib64/python3.5/http/client.py in _send_output(self, message_body)
#     909         del self._buffer[:]
#     910
# --> 911         self.send(msg)
#     912         if message_body is not None:
#     913             self.send(message_body)
#
# /usr/lib64/python3.5/http/client.py in send(self, data)
#     852         if self.sock is None:
#     853             if self.auto_open:
# --> 854                 self.connect()
#     855             else:
#     856                 raise NotConnected()
#
# /home/chio/.virtualenvs/sEnv/lib/python3.5/site-packages/requests/packages/urllib3/connection.py in connect(self)
#     158
#     159     def connect(self):
# --> 160         conn = self._new_conn()
#     161         self._prepare_conn(conn)
#     162
#
# /home/chio/.virtualenvs/sEnv/lib/python3.5/site-packages/requests/packages/urllib3/connection.py in _new_conn(self)
#     132
#     133         try:
# --> 134             conn = connection.create_connection(
#     135                 (self.host, self.port), self.timeout, **extra_kw)
#     136
#
# KeyboardInterrupt:
